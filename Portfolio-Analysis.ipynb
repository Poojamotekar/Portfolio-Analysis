# %% [markdown]
# <h1 style="color: #FF8C00;">Portfolio Analysis: Python Challenge</h1>
#
# ---
#
# **This challenge** represents a practical tech assignment designed to test your skills in portfolio analysis. Portfolio analysis is a systematic way to evaluate investment portfolios to optimize asset allocation and management. It involves a variety of financial metrics and visualizations to assess the performance and risk of different financial assets.
#
# - In this exercise, you will be required to perform a series of calculations and create visualizations to analyze a set of financial assets.
# - Your task is to develop the necessary code to accomplish each of these tasks effectively.
# - This challenge is an opportunity to demonstrate your ability to apply Python programming skills in a real-world financial context.

# %%
# 📚 Basic libraries
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# ⚙️ Settings
pd.set_option('display.max_columns', None) # display all columns
import warnings
warnings.filterwarnings('ignore') # ignore warnings

# %% [markdown]
# <h1 style="color: #00BFFF;">01 | Data Extraction</h1>

# %% [markdown]
# <h1 style="color: #FF8C00;">Exercise 1: Data Loading and Price Charting</h1>
#
# ---
#
# You are tasked with loading and analyzing financial data, which is foundational for effective portfolio management. Begin by loading the file named `asset_price_data.csv`, containing essential pricing information for various financial assets.
#
# Post data loading, your objective is to visualize this data through a time series graph.The integrity of your analysis depends heavily on your ability to visualize trends accurately while ensuring all asset price series begin at a uniform value.

# %% [markdown]
# <h3 style="color: #FF6347;">Data Loading</h3>

# %%
data = pd.read_csv('asset_price_data.csv')

# %%
data
# Out:
#            date    Asset1   Asset2     Asset3  Asset4  Asset5
# 0    2019-01-02  231.5061   55.875  25.649222  302.93   50.89
# 1    2019-01-03  231.0356   54.977  25.503047  302.11   50.41
# 2    2019-01-04  230.4026   56.129  26.147133  301.77   51.38
# 3    2019-01-07  230.0543   56.838  25.955277  302.33   52.14
# 4    2019-01-08  229.7012   56.895  26.137997  303.42   52.13
# ..          ...       ...      ...        ...     ...     ...
# 778  2021-12-27  249.9207  103.956  38.820000     NaN   70.11
# 779  2021-12-28  249.9368  104.526  39.115000     NaN   70.03
# 780  2021-12-29  248.7215  104.360  38.855000  342.46   69.81
# 781  2021-12-30  248.5485  104.663  38.985000  342.55   69.91
# 782  2021-12-31  248.7545  104.106  39.005000  342.59     NaN
#
# [783 rows x 6 columns]

# %% [markdown]
# <h2 style="color: #008080;">Exploring the Data (First Impression)</h2>

# %%
data.head(5)
# Out:
#          date    Asset1  Asset2     Asset3  Asset4  Asset5
# 0  2019-01-02  231.5061  55.875  25.649222  302.93   50.89
# 1  2019-01-03  231.0356  54.977  25.503047  302.11   50.41
# 2  2019-01-04  230.4026  56.129  26.147133  301.77   51.38
# 3  2019-01-07  230.0543  56.838  25.955277  302.33   52.14
# 4  2019-01-08  229.7012  56.895  26.137997  303.42   52.13

# %%
data.sample(5)
# Out:
#            date    Asset1   Asset2     Asset3  Asset4  Asset5
# 329  2020-04-07  244.4300   59.565  26.924522  294.41   40.64
# 332  2020-04-10       NaN      NaN        NaN     NaN     NaN
# 774  2021-12-21  251.4008  100.365  37.960000  342.13   67.93
# 1    2019-01-03  231.0356   54.977  25.503047  302.11   50.41
# 729  2021-10-19  249.0822   98.415  36.690439  341.99   70.55

# %%
data.shape
# Out:
# (783, 6)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 783 entries, 0 to 782
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    783 non-null    object
#  1   Asset1  770 non-null    float64
#  2   Asset2  770 non-null    float64
#  3   Asset3  770 non-null    float64
#  4   Asset4  734 non-null    float64
#  5   Asset5  763 non-null    float64
# dtypes: float64(5), object(1)
# memory usage: 36.8+ KB

# %%
# Convert 'date' column to datetime
data['date'] = pd.to_datetime(data['date'])

# Set 'date' column as index
data.set_index('date', inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 783 entries, 2019-01-02 to 2021-12-31
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Asset1  770 non-null    float64
#  1   Asset2  770 non-null    float64
#  2   Asset3  770 non-null    float64
#  3   Asset4  734 non-null    float64
#  4   Asset5  763 non-null    float64
# dtypes: float64(5)
# memory usage: 36.7 KB

# %%
data.describe().T
# Out:
#         count        mean        std         min         25%         50%  \
# Asset1  770.0  248.980188   6.845006  229.701200  246.868050  250.685350
# Asset2  770.0   76.112381  13.642823   48.516000   64.786250   72.003000
# Asset3  770.0   31.473296   3.304415   22.895066   29.281948   30.651198
# Asset4  734.0  327.356880  13.487611  272.790000  318.765000  326.665000
# Asset5  763.0   54.123198   8.185047   37.340000   49.120000   52.720000
#
#                75%      max
# Asset1  253.379275  259.110
# Asset2   88.973000  104.663
# Asset3   33.757265   39.115
# Asset4  340.155000  345.710
# Asset5   59.500000   71.050

# %% [markdown]
# <h2 style="color: #008080;">Copy as best practices</h2>

# %%
df=data.copy()

# %% [markdown]
# <h1 style="color: #00BFFF;">02 | Data Cleaning</h1>

# %%
df.head(5)
# Out:
#               Asset1  Asset2     Asset3  Asset4  Asset5
# date
# 2019-01-02  231.5061  55.875  25.649222  302.93   50.89
# 2019-01-03  231.0356  54.977  25.503047  302.11   50.41
# 2019-01-04  230.4026  56.129  26.147133  301.77   51.38
# 2019-01-07  230.0543  56.838  25.955277  302.33   52.14
# 2019-01-08  229.7012  56.895  26.137997  303.42   52.13

# %%
df.isnull().sum()
# Out:
# Asset1    13
# Asset2    13
# Asset3    13
# Asset4    49
# Asset5    20
# dtype: int64

# %% [markdown]
# <h2 style="color: #008080;">Feature Selection (Dropping unnecesary features)</h2>

# %%
df.dropna(thresh=4,inplace=True)

# %%
df.fillna(method='ffill',inplace=True) # fill Nan values with privous value

# %%
df.shape
# Out:
# (767, 5)

# %% [markdown]
# <h2 style="color: #008080;">Checking Null Values</h2>

# %%
df.isnull().sum()
# Out:
# Asset1    0
# Asset2    0
# Asset3    0
# Asset4    0
# Asset5    0
# dtype: int64

# %% [markdown]
# <h2 style="color: #008080;">Checking Duplicates</h2>

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df
# Out:
#               Asset1   Asset2     Asset3  Asset4  Asset5
# date
# 2019-01-02  231.5061   55.875  25.649222  302.93   50.89
# 2019-01-03  231.0356   54.977  25.503047  302.11   50.41
# 2019-01-04  230.4026   56.129  26.147133  301.77   51.38
# 2019-01-07  230.0543   56.838  25.955277  302.33   52.14
# 2019-01-08  229.7012   56.895  26.137997  303.42   52.13
# ...              ...      ...        ...     ...     ...
# 2021-12-27  249.9207  103.956  38.820000  342.40   70.11
# 2021-12-28  249.9368  104.526  39.115000  342.40   70.03
# 2021-12-29  248.7215  104.360  38.855000  342.46   69.81
# 2021-12-30  248.5485  104.663  38.985000  342.55   69.91
# 2021-12-31  248.7545  104.106  39.005000  342.59   69.91
#
# [767 rows x 5 columns]

# %% [markdown]
# <h2 style="color: #008080;">Checking Emtpy Spaces</h2>

# %%
df.eq(" ").sum()
# Out:
# Asset1    0
# Asset2    0
# Asset3    0
# Asset4    0
# Asset5    0
# dtype: int64

# %%
#<h2 style="color: #008080;">Moving our target to the right</h2>

# %%
# Setting the size of the plot
plt.figure(figsize=(16, 6))
plt.plot(df.index, df['Asset1'])  # As'date' is the index
plt.xlabel("Date")
plt.ylabel("Asset1")
plt.title("Pricing Information for Financial Asset1")
plt.show()

# %% [markdown]
# ## Insights :
# 1)You can see that it has a growth tendency
# 2)You can also see a sudden fall here because it is the start of lockdown during the pandemic

# %%
# Setting the size of the plot
plt.figure(figsize=(16, 6))

# Loop through each asset column and plot it
for column in df.columns:
    plt.plot(df.index, df[column], label=column)

plt.xlabel("Date")
plt.ylabel("Asset Price")
plt.title("Pricing Information for Financial Assets")
plt.legend()
plt.grid(True)
plt.show()

# %%
# Normalize asset prices to start at a uniform value
data_normalized = df.divide(df.iloc[0])

# %%
# Plot the time series graph
plt.figure(figsize=(10, 6))
for column in data_normalized.columns:
    plt.plot(data_normalized.index, data_normalized[column], label=column)

plt.title('Asset Price Time Series')
plt.xlabel('Date')
plt.ylabel('Normalized Price')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## Insights :
# the orange one is getting more expensive than the purple one
# the red one has a very stable price in the analysis period

# %%
# Convert index to datetime
data_normalized.index = pd.to_datetime(data_normalized.index)

# Extract year and month from the index
data_normalized['year'] = data_normalized.index.year
data_normalized['month'] = data_normalized.index.strftime('%b')

# Display the first few rows of the DataFrame
data_normalized.sample(5)
# Out:
#               Asset1    Asset2    Asset3    Asset4    Asset5  year month
# date
# 2020-10-13  1.110408  1.378345  1.143429  1.074077  0.930733  2020   Oct
# 2020-08-05  1.095759  1.301119  1.132713  1.063777  0.923855  2020   Aug
# 2020-09-24  1.100495  1.265718  1.114018  1.062391  0.909216  2020   Sep
# 2019-01-04  0.995233  1.004546  1.019412  0.996171  1.009629  2019   Jan
# 2019-04-11  1.023142  1.149530  1.154050  1.049153  1.089016  2019   Apr

# %%
plt.figure(figsize=(16, 7))

# Iterate over each asset column
for asset in data_normalized.columns[:-2]:  
    # Create point plot for the current asset
    sns.pointplot(x="month", y=asset, hue="year", data=data_normalized)
    plt.xlabel("Month")
    plt.ylabel(f"{asset} Price")
    plt.title(f"{asset} Price Segmented by Year")
    plt.legend(loc='upper right')
    plt.show()  # Show plot for each asset

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Setting the size of the plot
plt.figure(figsize=(16, 7))

# Iterate over each asset column (excluding 'year' and 'month' columns)
for asset in data_normalized.columns[:-2]:
    # Create a box plot for the current asset, segmented by month
    sns.catplot(x="month", y=asset, data=data_normalized, kind="box", order=['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'], height=8, aspect=float(16/7))
    plt.xlabel("Month")
    plt.ylabel("Price in $")
    plt.title(f"Price of {asset} Segmented by Month")

# Show the plot
plt.show()

# %% [markdown]
# ## Insights from Box Plot
# There are fluctuations in Asset prices of different months.
# The graph also shows outliers in Mar(Asset4) and Jan(Asset 5) which are represented by small dots.

# %% [markdown]
# <h1 style="color: #FF8C00;">Exercise 2: Daily Percentage Returns</h1>
#
# ---
#
# You are required to calculate the daily percentage returns for each financial asset. Utilize this data to accomplish the following:
# - Calculate the correlation matrix for the five assets.
# - Create a scatter plot comparing the returns of two specific assets.

# %%
#( today's price - yesterday's price ) / yesterday's price

# %%
# Daily returns calculation:
daily_returns_assets = df.pct_change()
daily_returns_assets.head()
# Out:
#               Asset1    Asset2    Asset3    Asset4    Asset5
# date
# 2019-01-02       NaN       NaN       NaN       NaN       NaN
# 2019-01-03 -0.002032 -0.016072 -0.005699 -0.002707 -0.009432
# 2019-01-04 -0.002740  0.020954  0.025255 -0.001125  0.019242
# 2019-01-07 -0.001512  0.012632 -0.007338  0.001856  0.014792
# 2019-01-08 -0.001535  0.001003  0.007040  0.003605 -0.000192

# %%
# Calculate correlation matrix for daily returns:
correlation_matrix= daily_returns_assets.corr()
correlation_matrix
# Out:
#           Asset1    Asset2    Asset3    Asset4    Asset5
# Asset1  1.000000 -0.084049 -0.057886  0.101756 -0.107674
# Asset2 -0.084049  1.000000  0.852533  0.527311  0.592160
# Asset3 -0.057886  0.852533  1.000000  0.511723  0.557768
# Asset4  0.101756  0.527311  0.511723  1.000000  0.421127
# Asset5 -0.107674  0.592160  0.557768  0.421127  1.000000

# %%
sns.heatmap(correlation_matrix, annot=True, cmap='viridis')
# Out:
# <Axes: >

# %%
#Extracting Asset 2 and 3 data:
asset2 = daily_returns_assets['Asset2']
asset3 = daily_returns_assets['Asset3']

# %%
# Create a scatter plot with a linear regression line
sns.lmplot(x='Asset2', y='Asset3', data=df, fit_reg=True)
plt.xlabel('Asset2')
plt.ylabel('Asset3')
plt.title('Scatter Plot with Linear Regression Line: Asset1 vs Asset2')
plt.grid(True)
plt.show()

# %%
#Extracting Asset data:
asset2 = daily_returns_assets['Asset2']
asset3 = daily_returns_assets['Asset3']

# %%
# Create Scatter Plot:
plt.figure(figsize=(10,6))
plt.title('Asset 2 and 3 Daily returns Comparison')
sns.scatterplot(x=asset2, y=asset3)
# Out:
# <Axes: title={'center': 'Asset 2 and 3 Daily returns Comparison'}, xlabel='Asset2', ylabel='Asset3'>

# %% [markdown]
# <h1 style="color: #FF8C00;">Exercise 3: Portfolio Analysis</h1>
# This third exercise focuses on calculating and analyzing the performance of a portfolio. Begin by loading the file named portfolio_weights.csv, which contains the daily weights of each asset in the portfolio.
#
# To complete the exercise, you will need to perform the following tasks:
# ---
#
# - Create an area chart of the asset weights.
# - Plot the historical cumulative returns of the portfolio.
# - Calculate the annualized return of the portfolio.
# - Determine the annualized volatility of the portfolio (using an annualization factor of 261 days).
# - Produce an area chart grouping asset weights by their categories, as detailed in the asset_information_data.csv.

# %%
portfolio_weights=pd.read_csv('portfolio_weights.csv')
asset_information=pd.read_csv('asset_information_data.csv')

# %%
asset_information
# Out:
#      Name        Family
# 0  Asset1  Fixed Income
# 1  Asset2  Fixed Income
# 2  Asset3        Equity
# 3  Asset4        Equity
# 4  Asset5   Alternative

# %%
portfolio_weights.head()
# Out:
#          date    Asset1    Asset2    Asset3   Asset4    Asset5
# 0  2019-01-02  0.225458  0.116255  0.265003  0.23031  0.162974
# 1  2019-01-03  0.225458  0.116255  0.265003  0.23031  0.162974
# 2  2019-01-04  0.225458  0.116255  0.265003  0.23031  0.162974
# 3  2019-01-07  0.225458  0.116255  0.265003  0.23031  0.162974
# 4  2019-01-08  0.225458  0.116255  0.265003  0.23031  0.162974

# %%
portfolio_weights.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 783 entries, 0 to 782
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    783 non-null    object
#  1   Asset1  783 non-null    float64
#  2   Asset2  783 non-null    float64
#  3   Asset3  783 non-null    float64
#  4   Asset4  783 non-null    float64
#  5   Asset5  783 non-null    float64
# dtypes: float64(5), object(1)
# memory usage: 36.8+ KB

# %%
# Convert 'date' column to datetime
portfolio_weights['date'] = pd.to_datetime(portfolio_weights['date'])

# Set 'date' column as index
portfolio_weights.set_index('date', inplace=True)

# %%
portfolio_weights.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 783 entries, 2019-01-02 to 2021-12-31
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Asset1  783 non-null    float64
#  1   Asset2  783 non-null    float64
#  2   Asset3  783 non-null    float64
#  3   Asset4  783 non-null    float64
#  4   Asset5  783 non-null    float64
# dtypes: float64(5)
# memory usage: 36.7 KB

# %%
portfolio_weights
# Out:
#               Asset1    Asset2    Asset3   Asset4    Asset5
# date
# 2019-01-02  0.225458  0.116255  0.265003  0.23031  0.162974
# 2019-01-03  0.225458  0.116255  0.265003  0.23031  0.162974
# 2019-01-04  0.225458  0.116255  0.265003  0.23031  0.162974
# 2019-01-07  0.225458  0.116255  0.265003  0.23031  0.162974
# 2019-01-08  0.225458  0.116255  0.265003  0.23031  0.162974
# ...              ...       ...       ...      ...       ...
# 2021-12-27  0.071307  0.266093  0.168775  0.33547  0.158356
# 2021-12-28  0.071307  0.266093  0.168775  0.33547  0.158356
# 2021-12-29  0.071307  0.266093  0.168775  0.33547  0.158356
# 2021-12-30  0.071307  0.266093  0.168775  0.33547  0.158356
# 2021-12-31  0.071307  0.266093  0.168775  0.33547  0.158356
#
# [783 rows x 5 columns]

# %%
portfolio_weights_returns_assets = portfolio_weights.pct_change()

# %%
# Stacked area plot
plt.figure(figsize=(10,6))
plt.stackplot(df.index,df['Asset1'], df['Asset2'], df['Asset3'], df['Asset4'], df['Asset5'], labels=['Asset1', 'Asset2', 'Asset3', 'Asset4', 'Asset5'])
plt.legend(loc='upper left')
plt.xlabel('Date')
plt.ylabel('Asset Value')
plt.title('Stacked Area Plot of Asset Values Over Time')
plt.show()

# %% [markdown]
# ### 3.2 Plot the historical cumulative returns of the portfolio.

# %% [markdown]
# ### Formula:cumulative_returns=(Current Value - Initial Value) / Initial Value

# %%
# Calculate daily returns (in weights %) of the portfolio
weights_returns = (daily_returns_assets * portfolio_weights).sum(axis=1)

# %%
# Cumulative returns
cumulative_returns = (1 + weights_returns).cumprod()

# %%
cumulative_returns
# Out:
# date
# 2019-01-02    1.000000
# 2019-01-03    0.994003
# 2019-01-04    1.005322
# 2019-01-07    1.007354
# 2019-01-08    1.009807
#                 ...
# 2021-12-27    1.385293
# 2021-12-28    1.388847
# 2021-12-29    1.385611
# 2021-12-30    1.387832
# 2021-12-31    1.386123
# Length: 783, dtype: float64

# %%
portfolio_daily_returns = (daily_returns_assets * portfolio_weights).sum(axis=1)

# %%
plt.figure(figsize=(10, 6))
plt.plot(cumulative_returns.index, cumulative_returns, color='blue', linestyle='-')
plt.title('Historical Cumulative Returns of the Portfolio')
plt.xlabel('Date')
plt.ylabel('Cumulative Return')
plt.grid(True)
plt.show()

# %% [markdown]
# #The direction of the line indicates whether the portfolio's value has been increasing or decreasing over the specified time period. An upward trend indicates positive returns, while a downward trend suggests negative returns.
# how quickly the line on a graph rises or falls. A steep line indicates a rapid change, while a less steep line suggests a slower change.

# %% [markdown]
# ### 3.3Calculate the annualized return of the portfolio.

# %%
# Step 1: Calculate the total return
portfolio_value_start = cumulative_returns.iloc[0]  # Initial portfolio value
portfolio_value_end = cumulative_returns.iloc[-1]  # Final portfolio value
total_return = (portfolio_value_end - portfolio_value_start) / portfolio_value_start

# Step 2: Determine the investment period
start_date = cumulative_returns.index[0]  # Start date of the investment
end_date = cumulative_returns.index[-1]   # End date of the investment
investment_period_days = (end_date - start_date).days
investment_period_years = investment_period_days / 365

# Step 3: Adjust to annual time
annualized_return = (((1 + total_return) ** (1 / investment_period_years)) - 1).round(2)

# Print the annualized return
print(f"Portfolio's Annual return: {annualized_return}")
# Out:
# Portfolio's Annual return: 0.12

# %%
#annualized_return = ((1 + cumulative_returns.iloc[-1]) ** (261 / len(cumulative_returns)) - 1) * 100
#annualized_return

# %% [markdown]
# ### Insights: An annualized return of 0.12 means that, on average, the portfolio has generated a return of 12% per year over the investment period.

# %% [markdown]
# ### 3.4 Determine the annualized volatility of the portfolio (using an annualization factor of 261 days).

# %%
annualized_volatility = portfolio_daily_returns.std() * (261 ** 0.5)
annualized_volatility
# Out:
# 0.08508030731654292

# %% [markdown]
# ### Insights :8.5% annualized volatility is relatively moderate. It indicates that the portfolio's returns fluctuate moderately over time. While it's not exceptionally high, it's also not very low, suggesting a moderate level of risk associated with the portfolio.

# %% [markdown]
# <h1 style="color: #00BFFF;">03 | EDA (Exploratory Data Analysis)</h1>

# %% [markdown]
# <h2 style="color: #008080;">Statistical information about the numerical columns</h2>

# %% [markdown]
# <h2 style="color: #008080;">Selecting numerical</h2>

# %% [markdown]
# <h2 style="color: #008080;">Checking Distributions</h2>

# %% [markdown]
# <h2 style="color: #008080;">Looking for Correlations</h2>

# %% [markdown]
# <h1 style="color: #00BFFF;">04 | Data Processing</h1>

# %% [markdown]
# <h2 style="color: #008080;">X-Y Split</h2>

# %% [markdown]
# <h2 style="color: #008080;">Normalizing the Data</h2>

# %% [markdown]
# <h1 style="color: #00BFFF;">05 | Modeling</h1>

# %% [markdown]
# <h2 style="color: #008080;">Train-Test Split</h2>

# %% [markdown]
# <h2 style="color: #008080;">Model Validation</h2>

# %% [markdown]
# <h1 style="color: #00BFFF;">06 | Improving the Model</h1>

# %% [markdown]
# <h1 style="color: #00BFFF;">07 | Reporting</h1>
